# %% [markdown]
# Plottest

# %%
import pandas as pd
# %matplotlib inline
df = pd.DataFrame({'Hello':[345,56,678,4,2]})
df
p = df.plot(figsize=(20,5), color='red')
p.set_title('Hello World', Fontsize=40)
p.set_xlabel('x axis')
p.set_ylabel('y axis', fontsize=18)
p.legend(['testing']);
